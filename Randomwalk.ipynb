# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
np.random.random()
# Out:
# 0.1351355826571793

# %%
x = np.random.random((1000,))
y = np.random.random((1000,))

# %%
fix, ax = plt.subplots(figsize=(8,8))

_ = ax.hist(x, bins=50)

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x, y,'o')
ax.set_title('plot')
# Out:
# Text(0.5, 1.0, 'plot')

# %%
prob = [0.5, 0.5]   
  

start = 0  
positions = [start] 
  
 
rr = np.random.random(100) 
downp = rr < prob[0] 
upp = rr > prob[1] 
  
  
for idownp, iupp in zip(downp, upp): 
    down = idownp and positions[-1] > -1
    up = iupp and positions[-1] < 1
    positions.append(positions[-1] - down + up) 
  

plt.plot(positions,'o') 
plt.show()

# %%
import pylab

n = 100000

x = np.zeros(n) 
y = np.zeros(n) 

a = 0.5* np.random.random()

for i in range(1, n): 
	val = random.randint(1, 4) 
	if val == 1: 
		x[i] = x[i - 1] + a
		y[i] = y[i - 1] 
	elif val == 2: 
		x[i] = x[i - 1] - a
		y[i] = y[i - 1] 
	elif val == 3: 
		x[i] = x[i - 1] 
		y[i] = y[i - 1] + a
	else: 
		x[i] = x[i - 1] 
		y[i] = y[i - 1] - a
	


pylab.plot(x, y) 
pylab.show()

# %%
import pylab

n = 100

x = np.zeros(n) 

a = 0.5* np.random.random()
for i in range(1, n): 
	val = random.randint(1, 2) 
	if val == 1: 
		x[i] = x[i - 1] + a
	elif val == 2: 
		x[i] = x[i - 1] - a

    

pylab.plot(x) 
pylab.show()

# %%
for i in range(1, n): 

    x[i] - x[i - 1] = z
    
    print(z)
# Out:
#   File "<ipython-input-41-f26cfe6f6309>", line 3
#     x[i] - x[i - 1] = z
#     ^
# SyntaxError: can't assign to operator

# %%
import pylab

n = 1000


r = np.zeros(n) 
theta = np.zeros(n) 

 
for i in range(1, n): 
	val = random.randint(1, 2) 
	if val == 1: 
		r[i] = 10000 * np.random.random()
		theta[i] = theta[i - 1] 
	elif val == 2: 
		r[i] = r[i - 1] 
		theta[i] = 1000 * np.random.random() 
        



x = r*np.sin(theta)
y = r*np.cos(theta)

pylab.plot(x,y,'o') 
pylab.show()
